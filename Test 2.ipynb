# %%
import numpy as np

# %%
import pandas as pd

# %%
pd.read_csv("klemetso2021.csv")
# Out:
#    Vuosi  Kk  Pv    Klo Aikavyöhyke  Kuukauden sadesumma (mm)  \
# 0   2021   1   1  00:00         UTC                      51.2
# 1   2021   2   1  00:00         UTC                      36.3
# 2   2021   3   1  00:00         UTC                      21.6
# 3   2021   4   1  00:00         UTC                      32.4
# 4   2021   5   1  00:00         UTC                      65.6
# 5   2021   6   1  00:00         UTC                      36.3
# 6   2021   7   1  00:00         UTC                      45.9
# 7   2021   8   1  00:00         UTC                      85.8
# 8   2021   9   1  00:00         UTC                      61.3
# 9   2021  10   1  00:00         UTC                      89.0
#
#    Kuukauden keskilämpötila (degC)
# 0                             -5.0
# 1                             -7.3
# 2                             -0.5
# 3                              3.2
# 4                              8.0
# 5                             16.7
# ...

# %%
vs = pd.read_csv("valsorarna.csv")
vs.head()
# Out:
#    Vuosi  Kk  Pv    Klo Aikavyöhyke  Pilvien määrä (1/8)  \
# 0   2021   1   1  00:00         UTC                  NaN
# 1   2021   1   1  00:10         UTC                  NaN
# 2   2021   1   1  00:20         UTC                  NaN
# 3   2021   1   1  00:30         UTC                  NaN
# 4   2021   1   1  00:40         UTC                  NaN
#
#    Ilmanpaine (msl) (hPa)  Sademäärä (mm)  Suhteellinen kosteus (%)  \
# 0                  1009.7             NaN                      93.0
# 1                  1009.7             NaN                      93.0
# 2                  1009.7             NaN                      92.0
# 3                  1009.8             NaN                      91.0
# 4                  1009.8             NaN                      91.0
#
#    Sateen intensiteetti (mm/h)  Lumensyvyys (cm)  Ilman lämpötila (degC)  \
# 0                          NaN               NaN                     2.3
# ...

# %%
vs["Ilman lämpötila (degC)"]
# Out:
# 0        2.3
# 1        2.3
# 2        2.3
# 3        2.4
# 4        2.3
#         ...
# 12092    0.9
# 12093    1.1
# 12094    1.0
# 12095    0.8
# 12096    0.8
# Name: Ilman lämpötila (degC), Length: 12097, dtype: float64
